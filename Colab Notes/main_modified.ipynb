# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip3 install pyYAML==6.0
# Out:
# ...
#      |████████████████████████████████| 596 kB 10.0 MB/s
# ...
#   Attempting uninstall: pyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
import os
os.chdir('/content/drive/MyDrive/COD310/Attack_practical_asv')

# %%
ls
# Out:
# Analysis.gdoc             images/                      __pycache__/
# attack_noob.py            LICENSE                      questions.md
# =.py         main.ipynb                   README.md
# attack.py                 main_.ipynb           SomeFile.txt
# augment.py                models/                      spectrogram_json_dict/
# checkpoint/               out_intra/                   spectrogram.py
# clean.py                  out_intra_00_30/             Testattack.py
# common_import.py          output/                      Testspeaker.py
# config/                   output.txt                   tools.py
# data/                     Paper_Overview_Prakhar.gdoc  Voting.sol
# datas/                    png_to_gif.py
# generate_adv_examples.py  points.md

# %%
# !python3 generate_adv_examples.py --wav_root ./data/cod310/LibriSpeech_dataset/test_clean/wav --wav_file ./datas/splits/test.txt --noise_root ./out_intra_00_30/step2/ --out_root ./output

# %%
# !python3 Testattack.py --config config/test_config.yaml
# Out:
# Loading speaker model...
# Embedding size is 512, encoder ASP.
# __L__.softmax.fc.weight is not in the model.
# __L__.softmax.fc.bias is not in the model.
# __L__.angleproto.w is not in the model.
# __L__.angleproto.b is not in the model.
# Model ./checkpoint/baseline_v2_ap.model loaded!
# Enrolling...
# Enrolling ok!
# 121 to 3575 attack success rate: 100.0
# 237 to 121 attack success rate: 100.0
# 1221 to 1995 attack success rate: 100.0
# 1284 to 121 attack success rate: 92.9
# 1580 to 1221 attack success rate: 100.0
# 1995 to 237 attack success rate: 100.0
# 2094 to 3570 attack success rate: 100.0
# 2961 to 121 attack success rate: 100.0
# 3570 to 1284 attack success rate: 100.0
# 3575 to 2961 attack success rate: 100.0
# 3729 to 5142 attack success rate: 100.0
# 4446 to 1995 attack success rate: 93.1
# 4507 to 121 attack success rate: 100.0
# 4970 to 5683 attack success rate: 100.0
# 4992 to 1580 attack success rate: 100.0
# Traceback (most recent call last):
# ...

# %%
start = 0
end = start+1
# !python3 attack_prakhar.py --config config/attack_config.yaml --num_start {start} --num_end {end}
# Out:
# Loading speaker model...
# Embedding size is 512, encoder ASP.
# __L__.softmax.fc.weight is not in the model.
# __L__.softmax.fc.bias is not in the model.
# __L__.angleproto.w is not in the model.
# __L__.angleproto.b is not in the model.
# Model checkpoint/baseline_v2_ap.model loaded!
# Enrolling...
# Enrolling ok!
# Intra-gender attack ...
# Num: 00
# step1: 00, 121 to 3575, loss:  1.4949
# step1: 01, 121 to 3575, loss:  1.4577
# step1: 02, 121 to 3575, loss:  1.4221
# step1: 03, 121 to 3575, loss:  1.3869
# step1: 04, 121 to 3575, loss:  1.3520
# step1: 05, 121 to 3575, loss:  1.3188
# step1: 06, 121 to 3575, loss:  1.2881
# step1: 07, 121 to 3575, loss:  1.2601
# step1: 08, 121 to 3575, loss:  1.2336
# step1: 09, 121 to 3575, loss:  1.2079
# step1: 10, 121 to 3575, loss:  1.1833
# step1: 11, 121 to 3575, loss:  1.1599
# step1: 12, 121 to 3575, loss:  1.1372
# step1: 13, 121 to 3575, loss:  1.1151
# step1: 14, 121 to 3575, loss:  1.0931
# step1: 15, 121 to 3575, loss:  1.0721
# ...

# %%
ls
# Out:
# Analysis.gdoc             images/                      questions.md
# attack_prakhar.py         LICENSE                      README.md
# attack.py                 main.ipynb                   SomeFile.txt
# augment.py                main_prakhar.ipynb           spectrogram_json_dict/
# checkpoint/               models/                      Testattack.py
# clean.py                  out_intra/                   test-clean.tar
# config/                   output.txt                   Testspeaker.py
# data/                     Paper_Overview_Prakhar.gdoc  tools.py
# datas/                    points.md
# generate_adv_examples.py  __pycache__/

# %%
file1 = "./spectrogram_json_dict/spectrogram_step_1_Num{}.json".format(start)
file2 = "./spectrogram_json_dict/spectrogram_step_2_Num{}.json".format(start)


# !curl -F "filename=@{file1}" http://1505-103-40-198-21.ngrok.io

print('Step1 dict sent successfully ...\n\n')

# !curl -F "filename=@{file2}" http://1505-103-40-198-21.ngrok.io
# Out:
# Step1 dict sent successfully ...
#
#
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# <title>Directory listing for /</title>
# </head>
# <body>
# <h1>Directory listing for /</h1>
# <hr>
# <ul>
# <li><a href="__pycache__/">__pycache__/</a></li>
# <li><a href="common_import.py">common_import.py</a></li>
# <li><a href="png_to_gif.py">png_to_gif.py</a></li>
# <li><a href="result.txt">result.txt</a></li>
# <li><a href="sample.wav">sample.wav</a></li>
# <li><a href="server.py">server.py</a></li>
# <li><a href="sound.mp3">sound.mp3</a></li>
# <li><a href="spectrogram.py">spectrogram.py</a></li>
# <li><a href="step1/">step1/</a></li>
# <li><a href="step1_gif/">step1_gif/</a></li>
# <li><a href="step1_png/">step1_png/</a></li>
# <li><a href="step2/">step2/</a></li>
# <li><a href="step2_gif/">step2_gif/</a></li>
# <li><a href="step2_png/">step2_png/</a></li>
# ...
